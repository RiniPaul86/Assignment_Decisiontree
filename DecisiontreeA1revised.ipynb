# %% [markdown]
# <a href="https://colab.research.google.com/github/RiniPaul86/Assignment_Decisiontree/blob/main/DecisiontreeA1revised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Drugs A, B, C, X, Y for Decision Trees{Rini Paul}

# %% [markdown]
# ####About Dataset
# Imagine that you are a medical researcher compiling data for a study. You have collected data about a set of patients, all of whom suffered from the same illness. During their course of treatment, each patient responded to one of 5 medications, Drug A, Drug B, Drug c, Drug x and y.
#
# Part of your job is to build a model to find out which drug might be appropriate for a future patient with the same illness. The features of this dataset are Age, Sex, Blood Pressure, and the Cholesterol of the patients, and the target is the drug that each patient responded to.
#
# It is a sample of multiclass classifier, and you can use the training part of the dataset to build a decision tree, and then use it to predict the class of a unknown patient, or to prescribe a drug to a new patient.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np

#Splitting the dataset into train and test
from sklearn.model_selection import train_test_split


#import the decisiontree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report

# for pre-processing
from sklearn import preprocessing

# %%
#import the datasets
drug = pd.read_csv("/content/drug200.csv")

# %%
drug.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
drug.ndim
# Out:
# 2

# %%
drug.shape
# Out:
# (200, 6)

# %%
drug.size
# Out:
# 1200

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
drug.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
drug.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
drug.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
drug_grp1 = drug.groupby(['Drug'])
drug_grp1[['BP']].value_counts()
# Out:
# Drug   BP
# drugA  HIGH      23
# drugB  HIGH      16
# drugC  LOW       16
# drugX  NORMAL    36
#        LOW       18
# drugY  HIGH      38
#        LOW       30
#        NORMAL    23
# dtype: int64

# %%
drug_grp2 = drug.groupby(['Drug'])
drug_grp2[['Cholesterol']].value_counts()
# Out:
# Drug   Cholesterol
# drugA  HIGH           12
#        NORMAL         11
# drugB  HIGH            8
#        NORMAL          8
# drugC  HIGH           16
# drugX  NORMAL         34
#        HIGH           20
# drugY  HIGH           47
#        NORMAL         44
# dtype: int64

# %%
drug_grp3 = drug.groupby(['Drug'])
drug_grp3[['Na_to_K','Age']].mean()
# Out:
#          Na_to_K        Age
# Drug
# drugA  10.918783  35.869565
# drugB  11.524375  62.500000
# drugC  10.633750  42.500000
# drugX  10.650556  44.018519
# drugY  22.374780  43.747253

# %%
drug['Drug'].value_counts()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %%
drug = drug.drop(['Sex'],axis = 1)

# %%
# use label encoder to convert drug into numbers
label_encoder = preprocessing.LabelEncoder()
drug['BP'] = label_encoder.fit_transform(drug['BP'])
drug['Cholesterol'] = label_encoder.fit_transform(drug['Cholesterol'])
drug.head()
# Out:
#    Age  BP  Cholesterol  Na_to_K   Drug
# 0   23   0            0   25.355  drugY
# 1   47   1            0   13.093  drugC
# 2   47   1            0   10.114  drugC
# 3   28   2            0    7.798  drugX
# 4   61   1            0   18.043  drugY

# %%
import seaborn as sns
sns.pairplot(drug)

# %% [markdown]
# ####Decision Tree

# %%
drug.iloc[:,0:5]
# Out:
#      Age  BP  Cholesterol  Na_to_K   Drug
# 0     23   0            0   25.355  drugY
# 1     47   1            0   13.093  drugC
# 2     47   1            0   10.114  drugC
# 3     28   2            0    7.798  drugX
# 4     61   1            0   18.043  drugY
# ..   ...  ..          ...      ...    ...
# 195   56   1            0   11.567  drugC
# 196   16   1            0   12.006  drugC
# 197   52   2            0    9.894  drugX
# 198   23   2            1   14.020  drugX
# 199   40   1            1   11.349  drugX
#
# [200 rows x 5 columns]

# %%
x = drug.iloc[:,0:4]
y = drug.iloc[:,4]

# %%
x
# Out:
#      Age  BP  Cholesterol  Na_to_K
# 0     23   0            0   25.355
# 1     47   1            0   13.093
# 2     47   1            0   10.114
# 3     28   2            0    7.798
# 4     61   1            0   18.043
# ..   ...  ..          ...      ...
# 195   56   1            0   11.567
# 196   16   1            0   12.006
# 197   52   2            0    9.894
# 198   23   2            1   14.020
# 199   40   1            1   11.349
#
# [200 rows x 4 columns]

# %%
y
# Out:
# 0      drugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      drugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %%
# Splitting the dataset into train and test

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=44)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((140, 4), (60, 4), (140,), (60,))

# %% [markdown]
# ####Building Decision Tree Classifier using Entropy as a Criterion

# %%
model =  DecisionTreeClassifier(criterion='entropy',max_depth = 4)

model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# ####Plot the Decsion Tree

# %%
tree.plot_tree(model)
# Out:
# [Text(0.625, 0.9, 'x[3] <= 14.829\nentropy = 1.907\nsamples = 140\nvalue = [18, 8, 12, 32, 70]'),
#  Text(0.5, 0.7, 'x[1] <= 0.5\nentropy = 1.814\nsamples = 70\nvalue = [18, 8, 12, 32, 0]'),
#  Text(0.25, 0.5, 'x[0] <= 53.0\nentropy = 0.89\nsamples = 26\nvalue = [18, 8, 0, 0, 0]'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0, 0]'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0]'),
#  Text(0.75, 0.5, 'x[1] <= 1.5\nentropy = 0.845\nsamples = 44\nvalue = [0, 0, 12, 32, 0]'),
#  Text(0.625, 0.3, 'x[2] <= 0.5\nentropy = 0.985\nsamples = 21\nvalue = [0, 0, 12, 9, 0]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0]'),
#  Text(0.75, 0.1, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0]'),
#  Text(0.875, 0.3, 'entropy = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0]'),
#  Text(0.75, 0.7, 'entropy = 0.0\nsamples = 70\nvalue = [0, 0, 0, 0, 70]')]

# %%
fn = ['Age','BP','Cholesterol','Na_to_K']
cn = ['drugY','drugX','drugA','drugC','drugB']
fig,axes = plt.subplots(nrows=1, ncols=1, figsize=(2,2), dpi=400)
tree.plot_tree(model,feature_names=fn,class_names = cn, filled=True)
# Out:
# [Text(0.625, 0.9, 'Na_to_K <= 14.829\nentropy = 1.907\nsamples = 140\nvalue = [18, 8, 12, 32, 70]\nclass = drugB'),
#  Text(0.5, 0.7, 'BP <= 0.5\nentropy = 1.814\nsamples = 70\nvalue = [18, 8, 12, 32, 0]\nclass = drugC'),
#  Text(0.25, 0.5, 'Age <= 53.0\nentropy = 0.89\nsamples = 26\nvalue = [18, 8, 0, 0, 0]\nclass = drugY'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0, 0]\nclass = drugY'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0]\nclass = drugX'),
#  Text(0.75, 0.5, 'BP <= 1.5\nentropy = 0.845\nsamples = 44\nvalue = [0, 0, 12, 32, 0]\nclass = drugC'),
#  Text(0.625, 0.3, 'Cholesterol <= 0.5\nentropy = 0.985\nsamples = 21\nvalue = [0, 0, 12, 9, 0]\nclass = drugA'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0]\nclass = drugA'),
#  Text(0.75, 0.1, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0]\nclass = drugC'),
#  Text(0.875, 0.3, 'entropy = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0]\nclass = drugC'),
#  Text(0.75, 0.7, 'entropy = 0.0\nsamples = 70\nvalue = [0, 0, 0, 0, 70]\nclass = drugB')]

# %% [markdown]
# ####Prediction on the Test data

# %%
preds = model.predict(x_test)

# %%
pd.Series(preds).value_counts()
# Out:
# drugX    22
# drugY    21
# drugA     7
# drugB     6
# drugC     4
# dtype: int64

# %%
preds
# Out:
# array(['drugX', 'drugY', 'drugY', 'drugY', 'drugY', 'drugX', 'drugB',
#        'drugX', 'drugX', 'drugA', 'drugY', 'drugX', 'drugX', 'drugB',
#        'drugY', 'drugY', 'drugX', 'drugX', 'drugY', 'drugC', 'drugY',
#        'drugY', 'drugB', 'drugC', 'drugY', 'drugX', 'drugX', 'drugB',
#        'drugX', 'drugY', 'drugY', 'drugY', 'drugX', 'drugX', 'drugX',
#        'drugX', 'drugC', 'drugA', 'drugY', 'drugY', 'drugA', 'drugA',
#        'drugA', 'drugB', 'drugA', 'drugY', 'drugX', 'drugY', 'drugX',
#        'drugY', 'drugC', 'drugX', 'drugA', 'drugB', 'drugX', 'drugX',
#        'drugX', 'drugX', 'drugY', 'drugY'], dtype=object)

# %%
y_test
# Out:
# 135    drugX
# 73     drugY
# 157    drugY
# 28     drugY
# 23     drugY
# 79     drugX
# 54     drugB
# 3      drugX
# 114    drugX
# 124    drugB
# 180    drugY
# 111    drugX
# 182    drugX
# 64     drugB
# 9      drugY
# 68     drugY
# 35     drugX
# 45     drugX
# 89     drugY
# 47     drugC
# 177    drugY
# 126    drugY
# 142    drugB
# 7      drugC
# 12     drugY
# 32     drugX
# 181    drugX
# 136    drugB
# 105    drugX
# 178    drugY
# 48     drugY
# 190    drugY
# 112    drugX
# 81     drugX
# 95     drugX
# 43     drugX
# 158    drugC
# 187    drugA
# 99     drugY
# 65     drugY
# 138    drugB
# 46     drugA
# 118    drugA
# 85     drugB
# 110    drugA
# 141    drugY
# 199    drugX
# 115    drugY
# 37     drugX
# 184    drugY
# 2      drugC
# 44     drugX
# 17     drugA
# 108    drugB
# 152    drugX
# 106    drugX
# 51     drugX
# 58     drugX
# 125    drugY
# 6      drugY
# Name: Drug, dtype: object

# %% [markdown]
# #####Crosstab : Way to understand the two way table between predicted vs actual

# %%
pd.crosstab(y_test,preds)
# Out:
# col_0  drugA  drugB  drugC  drugX  drugY
# Drug
# drugA      5      0      0      0      0
# drugB      2      6      0      0      0
# drugC      0      0      4      0      0
# drugX      0      0      0     22      0
# drugY      0      0      0      0     21

# %% [markdown]
# ### Accuracy of the above model

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, preds)
# Out:
# 0.9666666666666667

# %%
np.mean(preds==y_test)
# Out:
# 0.9666666666666667

# %%
x_test['preds']=preds

# %%
x_test['y_test']=y_test

# %%
x_test
# Out:
#      Age  BP  Cholesterol  Na_to_K  preds y_test
# 135   74   1            1   11.939  drugX  drugX
# 73    41   2            1   22.905  drugY  drugY
# 157   53   1            0   22.963  drugY  drugY
# 28    39   1            1   22.697  drugY  drugY
# 23    48   1            0   15.036  drugY  drugY
# 79    32   1            1   10.840  drugX  drugX
# 54    68   0            1   10.189  drugB  drugB
# 3     28   2            0    7.798  drugX  drugX
# 114   20   2            1    9.281  drugX  drugX
# 124   53   0            1   12.495  drugA  drugB
# 180   22   0            1   22.818  drugY  drugY
# 111   47   2            1    6.683  drugX  drugX
# 182   20   1            1   11.686  drugX  drugX
# 64    60   0            0   13.303  drugB  drugB
# 9     43   1            1   19.368  drugY  drugY
# 68    54   2            0   24.658  drugY  drugY
# 35    46   2            1    7.285  drugX  drugX
# 45    66   2            1    8.107  drugX  drugX
# 89    50   2            1   17.211  drugY  drugY
# 47    68   1            0   10.291  drugC  drugC
# 177   25   2            0   19.011  drugY  drugY
# 126   66   0            0   16.347  drugY  drugY
# 142   60   0            1    8.621  drugB  drugB
# 7     41   1            0   11.037  drugC  drugC
# 12    43   1            0   15.376  drugY  drugY
# 32    49   1            1   11.014  drugX  drugX
# 181   59   2            0   13.884  drugX  drugX
# 136   55   0            0   10.977  drugB  drugB
# 105   37   1            1    8.968  drugX  drugX
# 178   39   2            0   15.969  drugY  drugY
# 48    23   2            0   31.686  drugY  drugY
# 190   58   0            0   18.991  drugY  drugY
# 112   35   1            1    9.170  drugX  drugX
# 81    64   2            0    7.761  drugX  drugX
# 95    36   1            1   11.424  drugX  drugX
# 43    23   2            0   12.260  drugX  drugX
# 158   59   1            0   10.444  drugC  drugC
# 187   47   0            0   10.403  drugA  drugA
# 99    15   0            1   16.725  drugY  drugY
# 65    68   2            1   27.050  drugY  drugY
# 138   51   0            1   11.343  drugA  drugB
# 46    37   0            0   13.091  drugA  drugA
# 118   32   0            1   10.292  drugA  drugA
# 85    59   0            0   13.935  drugB  drugB
# 110   50   0            0    7.490  drugA  drugA
# 141   64   1            1   25.741  drugY  drugY
# 199   40   1            1   11.349  drugX  drugX
# 115   51   0            0   18.295  drugY  drugY
# 37    39   1            1   13.938  drugX  drugX
# 184   18   0            0   37.188  drugY  drugY
# 2     47   1            0   10.114  drugC  drugC
# 44    50   2            1   12.295  drugX  drugX
# 17    43   0            0   13.972  drugA  drugA
# 108   72   0            1    9.677  drugB  drugB
# 152   55   2            1    7.261  drugX  drugX
# 106   22   2            0   11.953  drugX  drugX
# 51    67   2            1   10.898  drugX  drugX
# 58    60   2            1   10.091  drugX  drugX
# 125   19   0            1   25.969  drugY  drugY
# 6     49   2            0   16.275  drugY  drugY
